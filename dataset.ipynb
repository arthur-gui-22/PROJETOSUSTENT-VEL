# %% [markdown]
# <a href="https://colab.research.google.com/github/arthur-gui-22/PROJETOS_DATA_SCIENCE-/blob/CODE-HTML/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python
import pandas as pd
import plotly.express as px

#simular um carregamento de dados
dp = pd.DataFrame({
    "ano":[2020]*5 + [2021]*5 + [2022]*5+ [2023]*5 + [2024]*5 + [2025]*5
    "cidade": ['Salvador','João Pessoa','Recife','Curitiba','São Paulo']*6,
    "pib": [
      53.2,52.4,47.4,78.8,61.0,16.9,
      57.8,56.4,50.7,82.8,66.1,18.6,
      61.1,60.1,51.7,84.0,70.6,19.3,
      62.7,64.1,51.8,85.4,73.8,20.4,
      63.5,67.0,52.4,87.1,77.1,21.1,
      63.8,67.4,54.6,96.0,82.4,22.2,
      58.9,65.1,50.3,88.3,76.0,21.3,
      62.9,73.4,54.9,98.0,81.5,23.5,
      66.1,77.8,58.2,105.2,86.4,25.2,
      70.2,82.5,61.8,112.4,91.7,27.0
    ]
})
#criar um gráfico animado (bibli)
fig = px.bar(
    dp,
    x='cidade',
    y='pib',
    color = 'cidade',
    animation_frame = 'ano',
    range_y=[0,110]
)

fig.show()
# Out:
#   File "/tmp/ipython-input-3352315827.py", line 7
#     "ano":[2020]*5 + [2021]*5 + [2022]*5+ [2023]*5 + [2024]*5 + [2025]*5
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
import plotly.express as px

#simular um carregamento de dados
dp = pd.DataFrame({
    "ano":[2020]*5 + [2021]*5 + [2022]*5+ [2023]*5 + [2024]*5 + [2025]*5,
    "cidade": ['Salvador','João Pessoa','Recife','Curitiba','São Paulo']*6,
    "pib": [
      53.2,52.4,47.4,78.8,61.0,16.9,
      57.8,56.4,50.7,82.8,66.1,18.6,
      61.1,60.1,51.7,84.0,70.6,19.3,
      62.7,64.1,51.8,85.4,73.8,20.4,
      63.5,67.0,52.4,87.1,77.1,21.1
    ] # Truncated to 30 elements to match 'ano' and 'cidade' lengths
})
#criar um gráfico animado (bibli)
fig = px.bar(
    dp,
    x='cidade',
    y='pib',
    color = 'cidade',
    animation_frame = 'ano',
    range_y=[0,100]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
